# %% [markdown]
# # Extracción, Transformación y Carga de datos (ETL)

# %%
import pandas as pd
import json
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.insert(0, '../')
import Herramientas as Herr

# %% [markdown]
# ### Carga de datos

# %%
fila = []

with open('../datasets/output_steam_games.json',encoding='utf-8') as r:
    for line in r.readlines():
        datos = json.loads(line)
        fila.append(datos)

data_output = pd.DataFrame(fila)
data_output
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
Herr.analizar_datos(data_output)
# Out:
#           Nombre              Tipos de Datos Únicos  % de Valores No Nulos  \
# 0      publisher   [<class 'float'>, <class 'str'>]                  20.00
# 1         genres  [<class 'float'>, <class 'list'>]                  23.95
# 2       app_name   [<class 'float'>, <class 'str'>]                  26.68
# 3          title   [<class 'float'>, <class 'str'>]                  24.98
# 4            url   [<class 'float'>, <class 'str'>]                  26.68
# 5   release_date   [<class 'float'>, <class 'str'>]                  24.96
# 6           tags  [<class 'float'>, <class 'list'>]                  26.54
# 7    reviews_url   [<class 'float'>, <class 'str'>]                  26.68
# 8          specs  [<class 'float'>, <class 'list'>]                  26.12
# 9          price   [<class 'float'>, <class 'str'>]                  25.54
# 10  early_access  [<class 'float'>, <class 'bool'>]                  26.68
# ...

# %% [markdown]
# ### Transformación de datos

# %%
filas_Nan= data_output[data_output.isna().all(axis=1)]
filas_Nan
# Out:
#       publisher genres app_name title  url release_date tags reviews_url  \
# 0           NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 1           NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 2           NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 3           NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 4           NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# ...         ...    ...      ...   ...  ...          ...  ...         ...
# 88305       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 88306       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 88307       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 88308       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 88309       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
#
#       specs price early_access   id developer
# ...

# %%
data_output = data_output.drop(filas_Nan.index)

# %%
Herr.analizar_datos(data_output)
# Out:
#           Nombre              Tipos de Datos Únicos  % de Valores No Nulos  \
# 0      publisher   [<class 'str'>, <class 'float'>]                  74.94
# 1         genres  [<class 'list'>, <class 'float'>]                  89.78
# 2       app_name   [<class 'str'>, <class 'float'>]                  99.99
# 3          title   [<class 'str'>, <class 'float'>]                  93.62
# 4            url                    [<class 'str'>]                 100.00
# 5   release_date   [<class 'str'>, <class 'float'>]                  93.57
# 6           tags  [<class 'list'>, <class 'float'>]                  99.49
# 7    reviews_url   [<class 'str'>, <class 'float'>]                  99.99
# 8          specs  [<class 'list'>, <class 'float'>]                  97.92
# 9          price   [<class 'float'>, <class 'str'>]                  95.71
# 10  early_access                   [<class 'bool'>]                 100.00
# ...

# %%
data_output_prueba = data_output['title'] == data_output['app_name']
data_output_prueba.value_counts()
# Out:
# True     29530
# False     2605
# Name: count, dtype: int64

# %%
data_output
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314                NaN                                                NaN
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444               NaN                                                NaN
#
# ...

# %% [markdown]
# Se observo que hay columnas las cuales no son necesarias para nuestra api y las eliminaremos, ellas son:
# * Url
# * Reviews_url
# * Tags
# * Specs

# %%
data_output = data_output.drop(['url','reviews_url','tags','specs'],axis=1)
data_output
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314                NaN                                                NaN
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444               NaN                                                NaN
#
# ...

# %%
data_output['release_date'].fillna('No date',inplace=True)
data_output['release_date'] = data_output['release_date'].apply(Herr.extraccion_anio_wstring)
data_output
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314                NaN                                                NaN
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444               NaN                                                NaN
#
# ...

# %%
duplicadas_id = data_output[data_output.duplicated(subset='id',keep=False)]
duplicadas_id_orden = duplicadas_id.sort_values(by='id')
duplicadas_id_orden
# Out:
#                                                 publisher  \
# 102204                                 Bethesda Softworks
# 102883                                 Bethesda Softworks
# 88384                                                 NaN
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 102204             [Action]                Wolfenstein II: The New Colossus
# 102883             [Action]                Wolfenstein II: The New Colossus
# 88384                   NaN                                             NaN
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title release_date  price  \
# 102204                Wolfenstein II: The New Colossus         2017  59.99
# 102883                Wolfenstein II: The New Colossus         2017  59.99
# ...

# %%
dropear = [102204,88384,119271]
data_output = data_output.drop(dropear)

# %%
Herr.analizar_datos(data_output)
# Out:
#          Nombre                Tipos de Datos Únicos  % de Valores No Nulos  \
# 0     publisher     [<class 'str'>, <class 'float'>]                  74.94
# 1        genres    [<class 'list'>, <class 'float'>]                  89.79
# 2      app_name     [<class 'str'>, <class 'float'>]                 100.00
# 3         title     [<class 'str'>, <class 'float'>]                  93.62
# 4  release_date  [<class 'str'>, <class 'NoneType'>]                  92.68
# 5         price     [<class 'float'>, <class 'str'>]                  95.71
# 6  early_access                     [<class 'bool'>]                 100.00
# 7            id                      [<class 'str'>]                 100.00
# 8     developer     [<class 'str'>, <class 'float'>]                  89.74
#
#    % de Valores Nulos  Cantidad de Valores Nulos
# 0               25.06                       8051
# 1               10.21                       3282
# 2                0.00                          1
# ...

# %%
columnas_Nan = ['publisher','genres','app_name','title','developer','release_date']
data_output[columnas_Nan] = data_output[columnas_Nan].fillna('No data')

# %%
data_output
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314            No data                                            No data
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444           No data                                            No data
#
# ...

# %%
data_output['price'].unique()
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, nan, 'Free', 10.99, 1.59, 14.99, 1.99, 59.99, 8.99,
#        6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49, 15.99, 1.25,
#        24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 119.99, 109.99,
#        149.99, 771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 3.0, 15.0, 5.49, 23.99, 49.0, 20.99,
#        10.93, 1.39, 'Free HITMAN™ Holiday Pack', 36.99, 4.49, 2.0, 4.0,
#        9.0, 234.99, 1.95, 1.5, 199.0, 189.0, 6.66, 27.99, 10.49, 129.99,
#        179.0, 26.99, 399.99, 31.99, 399.0, 20.0, 40.0, 3.33, 199.99,
#        22.99, 320.0, 38.85, 71.7, 59.95, 995.0, 27.49, 3.39, 6.0, 19.95,
# ...

# %%
strings_price = ['Free To Play','Free to Play','Free','Free Demo','Play for Free!','Install Now','Play WARMACHINE: Tactics Demo','Free Mod','Install Theme','Third-party','Play Now','Free HITMAN™ Holiday Pack','Play the Demo','Free to Try','Free Movie','Free to Use']
data_output['price'] = data_output['price'].replace(strings_price,0)
data_output['price'] = data_output['price'].replace('nan',None)
data_output['price'] = data_output['price'].fillna(0)
data_output = data_output[data_output['price'].apply(lambda x: not str(x).startswith('Starting at'))]
data_output['price'] = data_output['price'].astype(float)

# %%
Herr.analizar_datos(data_output)
# Out:
#          Nombre            Tipos de Datos Únicos  % de Valores No Nulos  \
# 0     publisher                  [<class 'str'>]                  100.0
# 1        genres  [<class 'list'>, <class 'str'>]                  100.0
# 2      app_name                  [<class 'str'>]                  100.0
# 3         title                  [<class 'str'>]                  100.0
# 4  release_date                  [<class 'str'>]                  100.0
# 5         price                [<class 'float'>]                  100.0
# 6  early_access                 [<class 'bool'>]                  100.0
# 7            id                  [<class 'str'>]                  100.0
# 8     developer                  [<class 'str'>]                  100.0
#
#    % de Valores Nulos  Cantidad de Valores Nulos
# 0                 0.0                          0
# 1                 0.0                          0
# 2                 0.0                          0
# 3                 0.0                          0
# ...

# %%
data_output = data_output.reset_index(drop=True)

# %%
data_output = data_output.explode('genres')
data_output
# Out:
#           publisher      genres             app_name                title  \
# 0         Kotoshiro      Action  Lost Summoner Kitty  Lost Summoner Kitty
# 0         Kotoshiro      Casual  Lost Summoner Kitty  Lost Summoner Kitty
# 0         Kotoshiro       Indie  Lost Summoner Kitty  Lost Summoner Kitty
# 0         Kotoshiro  Simulation  Lost Summoner Kitty  Lost Summoner Kitty
# 0         Kotoshiro    Strategy  Lost Summoner Kitty  Lost Summoner Kitty
# ...             ...         ...                  ...                  ...
# 32127  Laush Studio      Racing        Russian Roads        Russian Roads
# 32127  Laush Studio  Simulation        Russian Roads        Russian Roads
# 32128      SIXNAILS      Casual  EXIT 2 - Directions  EXIT 2 - Directions
# 32128      SIXNAILS       Indie  EXIT 2 - Directions  EXIT 2 - Directions
# 32129       No data     No data          Maze Run VR              No data
#
#       release_date  price early_access      id                 developer
# ...

# %% [markdown]
# ### Exportamos los datos

# %%
ruta = '../datasets/output.csv'

data_output.to_csv(ruta,index=False,encoding='utf-8')
