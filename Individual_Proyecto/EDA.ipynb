# %% [markdown]
# # Analisis Exploratorio de Datos (EDA)

# %%
import matplotlib_inline as plt
import seaborn as sns
import pandas as pd
import Herramientas as Herr

# %% [markdown]
# ### EDA de **australian_reviews**

# %% [markdown]
# #### Carga de datos

# %%
data_reviews = pd.read_csv('datasets/australian_reviews.csv',encoding='utf-8')
data_reviews
# Out:
#                      user_id  \
# 0          76561197970982479
# 1                    js41637
# 2                  evcentric
# 3                      doctr
# 4                  maplemage
# ...                      ...
# 59001     SKELETRONPRIMEISOP
# 59002      76561198141079508
# 59003            ShadowYT100
# 59004  bestcustomurlevermade
# 59005      76561198209894493
#
#                                                 user_url  posted  item_id  \
# 0      http://steamcommunity.com/profiles/76561197970...  2011.0     1250
# 1                   http://steamcommunity.com/id/js41637  2014.0   251610
# 2                 http://steamcommunity.com/id/evcentric     NaN   248820
# 3                     http://steamcommunity.com/id/doctr  2013.0   250320
# 4                 http://steamcommunity.com/id/maplemage  2014.0   211420
# ...                                                  ...     ...      ...
# 59001    http://steamcommunity.com/id/SKELETRONPRIMEISOP  2014.0      440
# 59002  http://steamcommunity.com/profiles/76561198141...  2014.0   304930
# 59003           http://steamcommunity.com/id/ShadowYT100  2015.0   265630
# 59004  http://steamcommunity.com/id/bestcustomurlever...  2015.0   304050
# 59005  http://steamcommunity.com/profiles/76561198209...     NaN      570
#
#                                                helpful  recommend  \
# 0                                       No ratings yet       True
# 1      15 of 20 people (75%) found this review helpful       True
# 2                                       No ratings yet       True
# 3       2 of 2 people (100%) found this review helpful       True
# 4      35 of 43 people (81%) found this review helpful       True
# ...                                                ...        ...
# 59001                                   No ratings yet       True
# 59002                                   No ratings yet       True
# 59003                                   No ratings yet       True
# 59004                                   No ratings yet       True
# 59005     0 of 2 people (0%) found this review helpful      False
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1      I know what you think when you see this title ...
# 2      A suitably punishing roguelike platformer.  Wi...
# 3      This game... is so fun. The fight sequences ha...
# 4                                                Git gud
# ...                                                  ...
# 59001  TF2 is alot of fun and its really good but the...
# 59002                              Fun game with friends
# 59003                                        So Fun!! :D
# 59004  This game is great. The only thing is,Why cant...
# 59005  DOTA 2.normal skill - 2ez for me>high skill - ...
#
# [59006 rows x 7 columns]

# %%
Herr.analizar_datos(data_reviews)
